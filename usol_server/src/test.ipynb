# %%
import requests
import json
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib
import warnings
warnings.filterwarnings("ignore")

# %%
url = "http://127.0.0.1:51001/leak/test"

# %%
import os
os.getcwd()
# Out:
# 'd:\\jhpark\\가온\\프로젝트\\1.유솔\\usol_server\\src'

# %%
base_data=pd.read_csv(r'd:\\jhpark\\가온\\프로젝트\\1.유솔\\3.데이터\use_test\test_imsil.csv')
base_data
# Out:
#       0         1         2         3         4         5          6  \
# 0   0.0  3.352941  3.352941  6.705882  6.705882  6.705882   6.705882
# 1   0.0  0.000000  0.000000  0.000000  0.000000  0.000000   2.921569
# 2   0.0  3.941176  3.941176  3.941176  3.941176  3.941176   3.941176
# 3   0.0  7.780392  9.725490  7.780392  9.725490  9.725490  11.670588
# 4   0.0  3.862745  3.862745  3.862745  4.635294  5.407843   3.862745
# ..  ...       ...       ...       ...       ...       ...        ...
# 57  0.0  3.847059  2.564706  3.847059  3.847059  3.847059   3.847059
# 58  0.0  3.352941  3.352941  4.470588  4.470588  5.588235  16.764706
# 59  0.0  3.984314  4.980392  3.984314  4.980392  3.984314   4.980392
# 60  0.0  2.886275  2.886275  2.886275  2.886275  2.886275   5.772549
# 61  0.0  3.960784  3.960784  3.960784  4.752941  4.752941   6.337255
#
#             7          8          9  ...       503       504       505  \
# ...

# %%
# n='가지고 있는 csv파일에서 모델에 넣을 변수의 수'
input_data = []
for idx, values in base_data.iloc[:5].iterrows():
    data = {
        "name":f"{idx}_name",
        "fft":[float(v) for v in values.values]}
    input_data.append(data)

# %%
result = requests.post(
    url=url,
    data=json.dumps(input_data)
)

# %%
result.json()
# Out:
# [{'names': '0_name', 'leak_pred': 1, 'dist_pred': False},
#  {'names': '1_name', 'leak_pred': 1, 'dist_pred': False},
#  {'names': '2_name', 'leak_pred': 1, 'dist_pred': False},
#  {'names': '3_name', 'leak_pred': 1, 'dist_pred': False},
#  {'names': '4_name', 'leak_pred': 1, 'dist_pred': False}]

# %%
input_data
# Out:
# [{'name': '0_name',
#   'fft': [0.0,
#    3.3529411764705883,
#    3.3529411764705883,
#    6.705882352941177,
#    6.705882352941177,
#    6.705882352941177,
#    6.705882352941177,
#    10.058823529411764,
#    10.058823529411764,
#    13.411764705882351,
#    16.764705882352942,
#    30.176470588235293,
#    77.11764705882352,
#    53.64705882352941,
#    40.23529411764706,
#    33.529411764705884,
#    30.176470588235293,
#    30.176470588235293,
#    26.823529411764707,
#    33.529411764705884,
#    50.294117647058826,
#    77.11764705882352,
#    120.70588235294116,
#    224.64705882352945,
#    600.1764705882352,
#    855.0,
#    204.52941176470588,
#    97.23529411764706,
#    43.588235294117645,
#    36.88235294117647,
#    36.88235294117647,
#    36.88235294117647,
#    36.88235294117647,
#    33.529411764705884,
#    33.529411764705884,
#    30.176470588235293,
#    36.88235294117647,
#    53.64705882352941,
#    36.88235294117647,
#    20.11764705882353,
# ...
