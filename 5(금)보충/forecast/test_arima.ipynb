# %%
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# %%
value = [1,2,3,4,5,4,3,2,1]*100

# %%
model = ARIMA(value[:-10], order=(2, 1, 2)).fit()
forecast = model.forecast(steps=10)
# Out:
# c:\Users\jhpark\anaconda3\envs\server\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
plt.figure(figsize=(20,5))
plt.plot(value[-10:], label="real")
plt.plot(forecast, label="predict")
plt.legend()
plt.show()

# %%
value = [36.57, 37.93, 36.34, 37.28, 36.51, 37.18, 37.02, 36.43, 36.3, 37.36, 36.99, 
36.75, 37.6, 36.82, 37.23, 37.11, 37.6, 37.7, 36.15, 36.43, 36.88, 36.15, 37.55, 37.42, 36.78, 36.29, 37.66, 37.95, 37.28, 37.08, 37.2, 36.32, 37.2, 37.56, 36.21, 36.24, 37.42, 36.51, 36.77, 36.59, 36.15, 37.28, 37.03, 37.51, 36.61, 36.84, 37.52, 37.77, 36.57, 36.56, 36.01, 36.88, 37.29, 37.11, 36.62, 36.9, 37.8, 36.7, 37.99, 37.07, 36.81, 36.35, 36.82, 37.05, 37.04, 37.14, 36.48, 37.13, 37.79, 36.82, 37.74, 37.63, 37.52, 37.88, 37.72, 37.86, 37.59, 36.56, 37.83, 37.03, 36.84, 36.96, 36.62, 37.72, 37.61, 36.53, 36.96, 36.43, 37.29, 37.92, 37.8, 37.1, 36.96, 36.93, 36.16, 36.55, 36.94, 36.83, 37.55, 36.14, 37.65, 37.89, 36.3, 36.35, 37.57, 37.41, 37.32, 37.66, 36.15, 37.44, 36.57, 37.75, 36.67, 36.05, 36.16, 36.89, 36.12, 36.08, 36.91, 37.37, 37.41]

# %%
plt.figure(figsize=(20,5))
plt.plot(value, label="real")
plt.legend()
plt.show()

# %%
model = ARIMA(value[:-10], order=(2, 0, 2)).fit()
forecast = model.forecast(steps=10)
# Out:
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model = ARIMA(value[:-10], order=(2, 0, 6)).fit()
forecast = model.forecast(steps=10)

plt.figure(figsize=(20,5))
plt.plot(value[-10:], label="real")
plt.plot(forecast, label="predict")
plt.legend()
plt.show()
# Out:
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# 랜덤 시드 설정
np.random.seed(42)

# 1시간 간격으로 2일치 데이터 생성
date_range = pd.date_range(start='2022-01-01', end='2022-01-03', freq='H')

# 기본 온도 패턴 (36도 + 주기적인 변동)
base_temp = 37 + 0.5 * np.sin(np.linspace(0, 4 * np.pi, len(date_range)))  # 36도와 38도 사이의 패턴
noise = np.random.normal(0, 0.1, len(date_range))  # 잡음 추가

# 최종 온도 데이터
temperature_data = base_temp + noise

plt.figure(figsize=(12, 6))
plt.plot(temperature_data, label='Observed Temperature', color='blue')
plt.grid()
plt.show()

# %%
from pmdarima.arima import auto_arima
df = [36.5, 37.81, 36.2, 37.62, 36.89, 36.34, 37.27, 36.17, 37.4, 36.5, 36.33, 37.36, 36.02, 37.8, 36.5, 36.66, 36.85, 37.16, 37.92, 36.9, 37.67, 37.54, 36.29, 37.7, 37.53, 36.47, 37.52, 37.22, 37.89, 37.78, 37.74, 36.57, 36.0, 37.0, 37.37, 37.72, 37.58, 37.6, 36.34, 37.57, 36.16, 36.96, 36.74, 36.45, 37.78, 37.81, 37.86, 37.64, 37.15, 36.47, 36.54, 
37.0, 36.09, 36.99, 37.25, 37.23, 37.58, 37.86, 36.59, 37.74, 37.64, 36.62, 36.67, 36.71, 
37.92, 37.44, 37.53, 37.21, 37.29, 36.35, 36.6, 37.64, 37.01, 36.47, 36.33, 36.21, 36.82, 
37.52, 37.94, 36.58, 36.26, 36.77, 37.74, 36.63, 36.51, 37.75, 37.66, 37.48, 37.55, 37.36, 36.42, 37.79, 37.03, 36.44, 37.4, 37.23, 37.74, 36.07, 36.38, 37.24, 36.79, 37.99, 37.77, 36.76, 37.7, 37.15, 36.07, 37.08, 37.22, 36.96, 36.66, 37.12, 37.52, 36.78, 37.96, 37.39, 36.31, 37.55, 36.1, 36.41, 37.21]
model_arima= auto_arima(df,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,suppress_warnings=True,stepwise=False,seasonal=False)

model_arima.fit(df)
# Out:
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1219.721, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=inf, Time=0.16 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=229.952, Time=0.11 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=231.933, Time=0.13 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=233.890, Time=0.16 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=232.687, Time=0.13 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.21 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.30 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=234.922, Time=0.15 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.26 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 2.009 seconds
# ARIMA(order=(1, 0, 1), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# 랜덤 시드 설정
np.random.seed(42)

# 1시간 간격으로 2일치 데이터 생성
date_range = pd.date_range(start='2022-01-01', end='2022-01-03', freq='H')

# 기본 온도 패턴 (36도 + 주기적인 변동)
base_temp = 37 + 0.5 * np.sin(np.linspace(0, 4 * np.pi, len(date_range)))  # 36도와 38도 사이의 패턴
noise = np.random.normal(0, 0.1, len(date_range))  # 잡음 추가

# 최종 온도 데이터
temperature_data = base_temp + noise

# 데이터프레임 생성
df = pd.DataFrame({'Date': date_range, 'Temperature': temperature_data})
df.set_index('Date', inplace=True)

# ARIMA 모델 학습
model = ARIMA(df['Temperature'], order=(3, 0, 2))
model_fit = model.fit()

# 예측 기간 설정 (다음 1시간 예측)
forecast_steps = 50
forecast = model_fit.forecast(steps=forecast_steps)

# 예측 결과를 데이터프레임으로 변환
# forecast_index = pd.date_range(start=df.index[-1] + pd.Timedelta(hours=1), periods=forecast_steps)
forecast_df = pd.DataFrame({'Forecast': forecast})#, index=forecast_index

# 결과 시각화
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Temperature'], label='Observed Temperature', color='blue')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Forecasted Temperature', color='red', linestyle='--')
plt.title('Temperature Forecast using ARIMA')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
from pmdarima.arima import auto_arima

model_arima= auto_arima(df,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,suppress_warnings=True,stepwise=False,seasonal=False)

model_arima.fit(df)
# Out:
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=494.875, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-73.309, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-70.385, Time=0.11 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=-67.177, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-71.379, Time=0.13 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.22 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.582 seconds
# ARIMA(order=(1, 0, 1), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# 랜덤 시드 설정
np.random.seed(42)

# 1시간 간격으로 2일치 데이터 생성
date_range = pd.date_range(start='2022-01-01', end='2022-01-03', freq='H')

# 큰 패턴 없이 랜덤하게 변동하는 데이터 생성
base_temp = 37 + np.random.normal(0, 0.1, len(date_range))

# 데이터프레임 생성
df = pd.DataFrame({'Date': date_range, 'Temperature': base_temp})
df.set_index('Date', inplace=True)

# ARIMA 모델 학습
model = ARIMA(df['Temperature'], order=(2, 0, 6))
model_fit = model.fit()

# 예측 기간 설정 (다음 1시간 예측)
forecast_steps = 50
forecast = model_fit.forecast(steps=forecast_steps)

# 예측 결과를 데이터프레임으로 변환
forecast_index = pd.date_range(start=df.index[-1] + pd.Timedelta(hours=1), periods=forecast_steps, freq='H')
forecast_df = pd.DataFrame({'Forecast': forecast}, index=forecast_index)

# 결과 시각화
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Temperature'], label='Observed Temperature', color='blue')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Forecasted Temperature', color='red', linestyle='--')
plt.title('Temperature Forecast using ARIMA')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\jhpark\anaconda3\envs\dl\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
