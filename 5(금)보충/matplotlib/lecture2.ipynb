# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_pickle(r'D:\바탕화면\지후의 생각\gaon\프로젝트\예천양수\data/3372_기동_group1_20161001_20170131_1.pkl')
df.head(5)
# Out:
#                          02-AI081  02-AI086-OUT  02-AI082  02-AI083  02-AI084  \
# Timestamp
# 2016-11-24 00:00:00.000  16.99632      20.44536  17.12448  16.86824  16.94893
# 2016-11-24 00:00:05.000  16.98517      20.36291  17.10276  16.86891  16.90845
# 2016-11-24 00:00:10.000  17.04843      20.37271  17.08687  16.80399  16.90551
# 2016-11-24 00:00:15.000  17.00600      20.36314  17.09232  16.85436  17.03350
# 2016-11-24 00:00:20.000  16.98701      20.33967  17.02383  16.82493  17.04300
#
#                          02-AI085  02-AI086  02-AI087  02-AI088  02-AI089  \
# Timestamp
# 2016-11-24 00:00:00.000  16.63700  20.44968  20.02048  19.74078  19.79583
# 2016-11-24 00:00:05.000  16.59428  20.34618  20.02940  19.70014  19.86934
# 2016-11-24 00:00:10.000  16.61712  20.32833  20.00078  19.83534  19.81656
# 2016-11-24 00:00:15.000  16.60303  20.36254  20.04268  19.81760  19.89623
# 2016-11-24 00:00:20.000  16.55208  20.39026  19.95548  19.75914  19.84623
#
# ...

# %%
fig, axes = plt.subplots(2,1,figsize=(9,3),sharex=True)
fig.suptitle('signal')
fig.tight_layout()
axes[0].plot(df['02-AI081'].values)
axes[1].plot(df['02-AI082'].values)

axes[0].set_title('02-AI081')
axes[1].set_title('02-AI082')

axes[0].grid()
axes[1].grid()

# %%
fig, axes = plt.subplots(5,1,figsize=(24,6),sharex=True)
fig.suptitle('signal')
fig.tight_layout()
for i,name in enumerate(df.columns[:5]):
    axes[i].plot(df[name].values)
    axes[i].set_title(name)
    axes[i].grid()
    axes[i].
